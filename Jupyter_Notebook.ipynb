# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Walaa Alghamdi**
#
# Biostatistian

# %% [markdown]
# _I am interested in data science because I like working with data and clean it to get results_

# %% [markdown]
# ### In cell 5, I am going to find the output of abaisc calcolation

# %%
5+7
# Out:
# 12

# %% [markdown]
# - data science
# - data analysis
# - data engineering
#
# 1. data science
# 2. data analysis
# 3. data engineering
#
# > data science larger than data analysis<br>
# while data analysis larger than data engineering
#
# <font color=red> data science</fomt>
#
# [click here to Google](https://www.google.com.sa/)
#
# ![DSC01124.jpg](attachment:85a1bf63-4b5a-4eab-8b95-beb74533e6ac.jpg)
